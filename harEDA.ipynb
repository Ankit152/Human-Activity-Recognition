# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('train.csv')

# %%
# five values from the top
train.head()
# Out:
#    tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  tBodyAccstdY  \
# 0       0.288585      -0.020294      -0.132905     -0.995279     -0.983111
# 1       0.278419      -0.016411      -0.123520     -0.998245     -0.975300
# 2       0.279653      -0.019467      -0.113462     -0.995380     -0.967187
# 3       0.279174      -0.026201      -0.123283     -0.996091     -0.983403
# 4       0.276629      -0.016570      -0.115362     -0.998139     -0.980817
#
#    tBodyAccstdZ  tBodyAccmadX  tBodyAccmadY  tBodyAccmadZ  tBodyAccmaxX  ...  \
# 0     -0.913526     -0.995112     -0.983185     -0.923527     -0.934724  ...
# 1     -0.960322     -0.998807     -0.974914     -0.957686     -0.943068  ...
# 2     -0.978944     -0.996520     -0.963668     -0.977469     -0.938692  ...
# 3     -0.990675     -0.997099     -0.982750     -0.989302     -0.938692  ...
# 4     -0.990482     -0.998321     -0.979672     -0.990441     -0.942469  ...
#
#    angletBodyAccMeangravity  angletBodyAccJerkMeangravityMean  \
# 0                 -0.112754                          0.030400
# 1                  0.053477                         -0.007435
# 2                 -0.118559                          0.177899
# 3                 -0.036788                         -0.012892
# 4                  0.123320                          0.122542
#
#    angletBodyGyroMeangravityMean  angletBodyGyroJerkMeangravityMean  \
# 0                      -0.464761                          -0.018446
# 1                      -0.732626                           0.703511
# 2                       0.100699                           0.808529
# 3                       0.640011                          -0.485366
# 4                       0.693578                          -0.615971
#
#    angleXgravityMean  angleYgravityMean  angleZgravityMean  subject  Activity  \
# 0          -0.841247           0.179941          -0.058627        1         5
# 1          -0.844788           0.180289          -0.054317        1         5
# 2          -0.848933           0.180637          -0.049118        1         5
# 3          -0.848649           0.181935          -0.047663        1         5
# 4          -0.847865           0.185151          -0.043892        1         5
#
#    ActivityName
# 0      STANDING
# 1      STANDING
# 2      STANDING
# 3      STANDING
# 4      STANDING
#
# [5 rows x 564 columns]

# %%
# information about the data
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7352 entries, 0 to 7351
# Columns: 564 entries, tBodyAccmeanX to ActivityName
# dtypes: float64(561), int64(2), object(1)
# memory usage: 31.6+ MB

# %%
# description of the data
train.describe()
# Out:
#        tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  \
# count    7352.000000    7352.000000    7352.000000   7352.000000
# mean        0.274488      -0.017695      -0.109141     -0.605438
# std         0.070261       0.040811       0.056635      0.448734
# min        -1.000000      -1.000000      -1.000000     -1.000000
# 25%         0.262975      -0.024863      -0.120993     -0.992754
# 50%         0.277193      -0.017219      -0.108676     -0.946196
# 75%         0.288461      -0.010783      -0.097794     -0.242813
# max         1.000000       1.000000       1.000000      1.000000
#
#        tBodyAccstdY  tBodyAccstdZ  tBodyAccmadX  tBodyAccmadY  tBodyAccmadZ  \
# count   7352.000000   7352.000000   7352.000000   7352.000000   7352.000000
# mean      -0.510938     -0.604754     -0.630512     -0.526907     -0.606150
# std        0.502645      0.418687      0.424073      0.485942      0.414122
# min       -0.999873     -1.000000     -1.000000     -1.000000     -1.000000
# 25%       -0.978129     -0.980233     -0.993591     -0.978162     -0.980251
# 50%       -0.851897     -0.859365     -0.950709     -0.857328     -0.857143
# 75%       -0.034231     -0.262415     -0.292680     -0.066701     -0.265671
# max        0.916238      1.000000      1.000000      0.967664      1.000000
#
#        tBodyAccmaxX  ...  fBodyBodyGyroJerkMagkurtosis  \
# count   7352.000000  ...                   7352.000000
# mean      -0.468604  ...                     -0.625294
# std        0.544547  ...                      0.307584
# min       -1.000000  ...                     -0.999765
# 25%       -0.936219  ...                     -0.845573
# 50%       -0.881637  ...                     -0.711692
# 75%       -0.017129  ...                     -0.503878
# max        1.000000  ...                      0.956845
#
#        angletBodyAccMeangravity  angletBodyAccJerkMeangravityMean  \
# count               7352.000000                       7352.000000
# mean                   0.008684                          0.002186
# std                    0.336787                          0.448306
# min                   -0.976580                         -1.000000
# 25%                   -0.121527                         -0.289549
# 50%                    0.009509                          0.008943
# 75%                    0.150865                          0.292861
# max                    1.000000                          1.000000
#
#        angletBodyGyroMeangravityMean  angletBodyGyroJerkMeangravityMean  \
# count                    7352.000000                        7352.000000
# mean                        0.008726                          -0.005981
# std                         0.608303                           0.477975
# min                        -1.000000                          -1.000000
# 25%                        -0.482273                          -0.376341
# 50%                         0.008735                          -0.000368
# 75%                         0.506187                           0.359368
# max                         0.998702                           0.996078
#
#        angleXgravityMean  angleYgravityMean  angleZgravityMean      subject  \
# count        7352.000000        7352.000000        7352.000000  7352.000000
# mean           -0.489547           0.058593          -0.056515    17.413085
# std             0.511807           0.297480           0.279122     8.975143
# min            -1.000000          -1.000000          -1.000000     1.000000
# 25%            -0.812065          -0.017885          -0.143414     8.000000
# 50%            -0.709417           0.182071           0.003181    19.000000
# 75%            -0.509079           0.248353           0.107659    26.000000
# max             1.000000           0.478157           1.000000    30.000000
#
#           Activity
# count  7352.000000
# mean      3.643362
# std       1.744802
# min       1.000000
# 25%       2.000000
# 50%       4.000000
# 75%       5.000000
# max       6.000000
#
# [8 rows x 563 columns]

# %%
# checking if there is any null values in the data
train.isnull().values.any()
# Out:
# False

# %%
# countplot of activities
plt.figure(figsize=(15,10))
plt.rcParams['font.family'] = 'Dejavu Sans'
sns.set_style('whitegrid')
sns.countplot(x=train['ActivityName'],data=train)
plt.title('Countplot of Activities',fontsize=20)
plt.xlabel('Activity Name',fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.savefig('./img/countplot.jpg')
plt.show()

# %%
# countplot subject wise
plt.figure(figsize=(15,10))
plt.rcParams['font.family'] = 'Dejavu Sans'
sns.set_style('whitegrid')
plt.title('Data provided by each user', fontsize=20)
sns.countplot(x='subject',hue='ActivityName', data = train)
plt.xlabel('Subject',fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.savefig('./img/subject.jpg')
plt.show()

# %%
from sklearn.manifold import TSNE

# %%
# performs t-sne with different perplexity values and their repective plots..
def perform_tsne(X_data, y_data, perplexities, n_iter=1000, img_name_prefix='t-sne'):
        
    for index,perplexity in enumerate(perplexities):
        # perform t-sne
        print('\nperforming tsne with perplexity {} and with {} iterations at max'.format(perplexity, n_iter))
        X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
        print('Done..')
        
        # prepare the data for seaborn         
        print('Creating plot for this t-sne visualization..')
        df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})
        
        # draw the plot in appropriate place in the grid
        plt.figure(figsize=(10,10))
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, size=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
        plt.xlabel('X',fontsize=15)
        plt.ylabel('Y',fontsize=15)
        img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
        print('saving this plot as image in present working directory...')
        plt.savefig('./img/'+img_name)
        plt.show()
        print('Done')

# %%
X_pre_tsne = train.drop(['subject', 'Activity','ActivityName'], axis=1)
y_pre_tsne = train['ActivityName']
perform_tsne(X_data = X_pre_tsne,y_data=y_pre_tsne, perplexities =[2,5,10,20,50])
# Out:
# performing tsne with perplexity 2 and with 1000 iterations at max
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.792s...
# [t-SNE] Computed neighbors for 7352 samples in 39.918s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.635854
# [t-SNE] Computed conditional probabilities in 0.022s
# [t-SNE] Iteration 50: error = 124.6571655, gradient norm = 0.0317270 (50 iterations in 2.268s)
# [t-SNE] Iteration 100: error = 107.1794281, gradient norm = 0.0261539 (50 iterations in 1.598s)
# [t-SNE] Iteration 150: error = 100.9955750, gradient norm = 0.0213143 (50 iterations in 1.361s)
# [t-SNE] Iteration 200: error = 97.5415039, gradient norm = 0.0157064 (50 iterations in 1.379s)
# [t-SNE] Iteration 250: error = 95.2210312, gradient norm = 0.0140040 (50 iterations in 1.286s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 95.221031
# [t-SNE] Iteration 300: error = 4.1155987, gradient norm = 0.0015602 (50 iterations in 1.194s)
# [t-SNE] Iteration 350: error = 3.2071810, gradient norm = 0.0010123 (50 iterations in 1.171s)
# [t-SNE] Iteration 400: error = 2.7796521, gradient norm = 0.0007185 (50 iterations in 1.250s)
# [t-SNE] Iteration 450: error = 2.5160100, gradient norm = 0.0005649 (50 iterations in 1.213s)
# [t-SNE] Iteration 500: error = 2.3326731, gradient norm = 0.0004845 (50 iterations in 1.222s)
# [t-SNE] Iteration 550: error = 2.1949360, gradient norm = 0.0004207 (50 iterations in 1.226s)
# [t-SNE] Iteration 600: error = 2.0859013, gradient norm = 0.0003662 (50 iterations in 1.237s)
# [t-SNE] Iteration 650: error = 1.9960208, gradient norm = 0.0003323 (50 iterations in 1.216s)
# [t-SNE] Iteration 700: error = 1.9204073, gradient norm = 0.0003008 (50 iterations in 1.228s)
# [t-SNE] Iteration 750: error = 1.8555897, gradient norm = 0.0002782 (50 iterations in 1.222s)
# [t-SNE] Iteration 800: error = 1.7989646, gradient norm = 0.0002570 (50 iterations in 1.262s)
# [t-SNE] Iteration 850: error = 1.7488986, gradient norm = 0.0002385 (50 iterations in 1.241s)
# [t-SNE] Iteration 900: error = 1.7043191, gradient norm = 0.0002241 (50 iterations in 1.243s)
# [t-SNE] Iteration 950: error = 1.6641953, gradient norm = 0.0002110 (50 iterations in 1.254s)
# [t-SNE] Iteration 1000: error = 1.6279142, gradient norm = 0.0002037 (50 iterations in 1.260s)
# [t-SNE] KL divergence after 1000 iterations: 1.627914
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\ankit\anaconda3\envs\tf_gpu\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 5 and with 1000 iterations at max
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.780s...
# [t-SNE] Computed neighbors for 7352 samples in 32.493s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.961265
# [t-SNE] Computed conditional probabilities in 0.038s
# [t-SNE] Iteration 50: error = 113.9385834, gradient norm = 0.0207341 (50 iterations in 1.636s)
# [t-SNE] Iteration 100: error = 98.2450714, gradient norm = 0.0148703 (50 iterations in 1.295s)
# [t-SNE] Iteration 150: error = 93.4184494, gradient norm = 0.0098250 (50 iterations in 1.233s)
# [t-SNE] Iteration 200: error = 91.3290176, gradient norm = 0.0066643 (50 iterations in 1.273s)
# [t-SNE] Iteration 250: error = 90.0891724, gradient norm = 0.0055421 (50 iterations in 1.217s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 90.089172
# [t-SNE] Iteration 300: error = 3.5750561, gradient norm = 0.0014602 (50 iterations in 1.207s)
# [t-SNE] Iteration 350: error = 2.8158057, gradient norm = 0.0007487 (50 iterations in 1.235s)
# [t-SNE] Iteration 400: error = 2.4353540, gradient norm = 0.0005233 (50 iterations in 1.275s)
# [t-SNE] Iteration 450: error = 2.2184098, gradient norm = 0.0004034 (50 iterations in 1.242s)
# [t-SNE] Iteration 500: error = 2.0739048, gradient norm = 0.0003296 (50 iterations in 1.260s)
# [t-SNE] Iteration 550: error = 1.9687866, gradient norm = 0.0002787 (50 iterations in 1.249s)
# [t-SNE] Iteration 600: error = 1.8875613, gradient norm = 0.0002474 (50 iterations in 1.281s)
# [t-SNE] Iteration 650: error = 1.8225489, gradient norm = 0.0002178 (50 iterations in 1.262s)
# [t-SNE] Iteration 700: error = 1.7688957, gradient norm = 0.0001951 (50 iterations in 1.281s)
# [t-SNE] Iteration 750: error = 1.7236147, gradient norm = 0.0001781 (50 iterations in 1.271s)
# [t-SNE] Iteration 800: error = 1.6846578, gradient norm = 0.0001632 (50 iterations in 1.292s)
# [t-SNE] Iteration 850: error = 1.6510317, gradient norm = 0.0001526 (50 iterations in 1.283s)
# [t-SNE] Iteration 900: error = 1.6214530, gradient norm = 0.0001423 (50 iterations in 1.258s)
# [t-SNE] Iteration 950: error = 1.5948399, gradient norm = 0.0001331 (50 iterations in 1.285s)
# [t-SNE] Iteration 1000: error = 1.5710590, gradient norm = 0.0001257 (50 iterations in 1.314s)
# [t-SNE] KL divergence after 1000 iterations: 1.571059
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\ankit\anaconda3\envs\tf_gpu\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 10 and with 1000 iterations at max
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.781s...
# [t-SNE] Computed neighbors for 7352 samples in 32.856s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.133828
# [t-SNE] Computed conditional probabilities in 0.072s
# [t-SNE] Iteration 50: error = 105.7164078, gradient norm = 0.0188857 (50 iterations in 1.800s)
# [t-SNE] Iteration 100: error = 90.4246216, gradient norm = 0.0099190 (50 iterations in 1.416s)
# [t-SNE] Iteration 150: error = 87.3645248, gradient norm = 0.0057126 (50 iterations in 1.334s)
# [t-SNE] Iteration 200: error = 86.1248627, gradient norm = 0.0037695 (50 iterations in 1.388s)
# [t-SNE] Iteration 250: error = 85.4231415, gradient norm = 0.0034269 (50 iterations in 1.347s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.423141
# [t-SNE] Iteration 300: error = 3.1344883, gradient norm = 0.0013860 (50 iterations in 1.310s)
# [t-SNE] Iteration 350: error = 2.4950881, gradient norm = 0.0006475 (50 iterations in 1.288s)
# [t-SNE] Iteration 400: error = 2.1752999, gradient norm = 0.0004226 (50 iterations in 1.317s)
# [t-SNE] Iteration 450: error = 1.9910369, gradient norm = 0.0003154 (50 iterations in 1.446s)
# [t-SNE] Iteration 500: error = 1.8729775, gradient norm = 0.0002541 (50 iterations in 1.371s)
# [t-SNE] Iteration 550: error = 1.7897898, gradient norm = 0.0002099 (50 iterations in 1.395s)
# [t-SNE] Iteration 600: error = 1.7272643, gradient norm = 0.0001819 (50 iterations in 1.372s)
# [t-SNE] Iteration 650: error = 1.6781687, gradient norm = 0.0001610 (50 iterations in 1.360s)
# [t-SNE] Iteration 700: error = 1.6384826, gradient norm = 0.0001442 (50 iterations in 1.398s)
# [t-SNE] Iteration 750: error = 1.6055666, gradient norm = 0.0001311 (50 iterations in 1.456s)
# [t-SNE] Iteration 800: error = 1.5780740, gradient norm = 0.0001203 (50 iterations in 1.421s)
# [t-SNE] Iteration 850: error = 1.5546722, gradient norm = 0.0001115 (50 iterations in 1.478s)
# [t-SNE] Iteration 900: error = 1.5344491, gradient norm = 0.0001044 (50 iterations in 1.526s)
# [t-SNE] Iteration 950: error = 1.5169718, gradient norm = 0.0000982 (50 iterations in 1.428s)
# [t-SNE] Iteration 1000: error = 1.5019145, gradient norm = 0.0000935 (50 iterations in 1.707s)
# [t-SNE] KL divergence after 1000 iterations: 1.501915
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\ankit\anaconda3\envs\tf_gpu\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 20 and with 1000 iterations at max
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.794s...
# [t-SNE] Computed neighbors for 7352 samples in 42.315s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.274335
# [t-SNE] Computed conditional probabilities in 0.161s
# [t-SNE] Iteration 50: error = 97.2604752, gradient norm = 0.0250341 (50 iterations in 1.947s)
# [t-SNE] Iteration 100: error = 83.7401962, gradient norm = 0.0077614 (50 iterations in 1.702s)
# [t-SNE] Iteration 150: error = 81.8656845, gradient norm = 0.0039807 (50 iterations in 1.619s)
# [t-SNE] Iteration 200: error = 81.1398773, gradient norm = 0.0036800 (50 iterations in 1.514s)
# [t-SNE] Iteration 250: error = 80.7291489, gradient norm = 0.0020198 (50 iterations in 1.576s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.729149
# [t-SNE] Iteration 300: error = 2.7048292, gradient norm = 0.0013131 (50 iterations in 1.511s)
# [t-SNE] Iteration 350: error = 2.1681080, gradient norm = 0.0005791 (50 iterations in 1.511s)
# [t-SNE] Iteration 400: error = 1.9171355, gradient norm = 0.0003482 (50 iterations in 1.533s)
# [t-SNE] Iteration 450: error = 1.7701184, gradient norm = 0.0002475 (50 iterations in 1.535s)
# [t-SNE] Iteration 500: error = 1.6761587, gradient norm = 0.0001920 (50 iterations in 1.522s)
# [t-SNE] Iteration 550: error = 1.6115340, gradient norm = 0.0001605 (50 iterations in 1.529s)
# [t-SNE] Iteration 600: error = 1.5649049, gradient norm = 0.0001375 (50 iterations in 1.609s)
# [t-SNE] Iteration 650: error = 1.5295833, gradient norm = 0.0001190 (50 iterations in 1.515s)
# [t-SNE] Iteration 700: error = 1.5021325, gradient norm = 0.0001069 (50 iterations in 1.579s)
# [t-SNE] Iteration 750: error = 1.4802657, gradient norm = 0.0000983 (50 iterations in 1.572s)
# [t-SNE] Iteration 800: error = 1.4626580, gradient norm = 0.0000897 (50 iterations in 1.598s)
# [t-SNE] Iteration 850: error = 1.4485613, gradient norm = 0.0000836 (50 iterations in 1.576s)
# [t-SNE] Iteration 900: error = 1.4368422, gradient norm = 0.0000784 (50 iterations in 1.599s)
# [t-SNE] Iteration 950: error = 1.4268000, gradient norm = 0.0000762 (50 iterations in 1.601s)
# [t-SNE] Iteration 1000: error = 1.4182749, gradient norm = 0.0000742 (50 iterations in 1.594s)
# [t-SNE] KL divergence after 1000 iterations: 1.418275
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\ankit\anaconda3\envs\tf_gpu\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 50 and with 1000 iterations at max
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.786s...
# [t-SNE] Computed neighbors for 7352 samples in 38.961s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.437672
# [t-SNE] Computed conditional probabilities in 0.396s
# [t-SNE] Iteration 50: error = 87.3148270, gradient norm = 0.0062080 (50 iterations in 2.769s)
# [t-SNE] Iteration 100: error = 76.0210648, gradient norm = 0.0060116 (50 iterations in 2.714s)
# [t-SNE] Iteration 150: error = 74.7410660, gradient norm = 0.0024327 (50 iterations in 3.501s)
# [t-SNE] Iteration 200: error = 74.3282013, gradient norm = 0.0016117 (50 iterations in 3.062s)
# [t-SNE] Iteration 250: error = 74.1337280, gradient norm = 0.0011477 (50 iterations in 2.963s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.133728
# [t-SNE] Iteration 300: error = 2.1645873, gradient norm = 0.0011974 (50 iterations in 2.494s)
# [t-SNE] Iteration 350: error = 1.7624708, gradient norm = 0.0004886 (50 iterations in 2.228s)
# [t-SNE] Iteration 400: error = 1.5923524, gradient norm = 0.0002835 (50 iterations in 2.269s)
# [t-SNE] Iteration 450: error = 1.4976139, gradient norm = 0.0001906 (50 iterations in 2.526s)
# [t-SNE] Iteration 500: error = 1.4372760, gradient norm = 0.0001426 (50 iterations in 3.204s)
# [t-SNE] Iteration 550: error = 1.3956758, gradient norm = 0.0001134 (50 iterations in 2.427s)
# [t-SNE] Iteration 600: error = 1.3658514, gradient norm = 0.0000934 (50 iterations in 2.405s)
# [t-SNE] Iteration 650: error = 1.3446896, gradient norm = 0.0000826 (50 iterations in 2.549s)
# [t-SNE] Iteration 700: error = 1.3290898, gradient norm = 0.0000751 (50 iterations in 2.397s)
# [t-SNE] Iteration 750: error = 1.3176793, gradient norm = 0.0000693 (50 iterations in 2.246s)
# [t-SNE] Iteration 800: error = 1.3090482, gradient norm = 0.0000620 (50 iterations in 2.405s)
# [t-SNE] Iteration 850: error = 1.3021585, gradient norm = 0.0000615 (50 iterations in 2.358s)
# [t-SNE] Iteration 900: error = 1.2963953, gradient norm = 0.0000577 (50 iterations in 2.510s)
# [t-SNE] Iteration 950: error = 1.2915760, gradient norm = 0.0000556 (50 iterations in 3.006s)
# [t-SNE] Iteration 1000: error = 1.2874614, gradient norm = 0.0000522 (50 iterations in 3.308s)
# [t-SNE] KL divergence after 1000 iterations: 1.287461
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\ankit\anaconda3\envs\tf_gpu\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
