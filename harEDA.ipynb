# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('train.csv')

# %%
# five values from the top
train.head()
# Out:
#    tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  tBodyAccstdY  \
# 0       0.288585      -0.020294      -0.132905     -0.995279     -0.983111
# 1       0.278419      -0.016411      -0.123520     -0.998245     -0.975300
# 2       0.279653      -0.019467      -0.113462     -0.995380     -0.967187
# 3       0.279174      -0.026201      -0.123283     -0.996091     -0.983403
# 4       0.276629      -0.016570      -0.115362     -0.998139     -0.980817
#
#    tBodyAccstdZ  tBodyAccmadX  tBodyAccmadY  tBodyAccmadZ  tBodyAccmaxX  ...  \
# 0     -0.913526     -0.995112     -0.983185     -0.923527     -0.934724  ...
# 1     -0.960322     -0.998807     -0.974914     -0.957686     -0.943068  ...
# 2     -0.978944     -0.996520     -0.963668     -0.977469     -0.938692  ...
# 3     -0.990675     -0.997099     -0.982750     -0.989302     -0.938692  ...
# 4     -0.990482     -0.998321     -0.979672     -0.990441     -0.942469  ...
#
#    angletBodyAccMeangravity  angletBodyAccJerkMeangravityMean  \
# 0                 -0.112754                          0.030400
# 1                  0.053477                         -0.007435
# 2                 -0.118559                          0.177899
# 3                 -0.036788                         -0.012892
# 4                  0.123320                          0.122542
#
#    angletBodyGyroMeangravityMean  angletBodyGyroJerkMeangravityMean  \
# 0                      -0.464761                          -0.018446
# 1                      -0.732626                           0.703511
# 2                       0.100699                           0.808529
# 3                       0.640011                          -0.485366
# 4                       0.693578                          -0.615971
#
#    angleXgravityMean  angleYgravityMean  angleZgravityMean  subject  Activity  \
# 0          -0.841247           0.179941          -0.058627        1         5
# 1          -0.844788           0.180289          -0.054317        1         5
# 2          -0.848933           0.180637          -0.049118        1         5
# 3          -0.848649           0.181935          -0.047663        1         5
# 4          -0.847865           0.185151          -0.043892        1         5
#
#    ActivityName
# 0      STANDING
# 1      STANDING
# 2      STANDING
# 3      STANDING
# 4      STANDING
#
# [5 rows x 564 columns]

# %%
# information about the data
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7352 entries, 0 to 7351
# Columns: 564 entries, tBodyAccmeanX to ActivityName
# dtypes: float64(561), int64(2), object(1)
# memory usage: 31.6+ MB

# %%
# description of the data
train.describe()
# Out:
#        tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  \
# count    7352.000000    7352.000000    7352.000000   7352.000000
# mean        0.274488      -0.017695      -0.109141     -0.605438
# std         0.070261       0.040811       0.056635      0.448734
# min        -1.000000      -1.000000      -1.000000     -1.000000
# 25%         0.262975      -0.024863      -0.120993     -0.992754
# 50%         0.277193      -0.017219      -0.108676     -0.946196
# 75%         0.288461      -0.010783      -0.097794     -0.242813
# max         1.000000       1.000000       1.000000      1.000000
#
#        tBodyAccstdY  tBodyAccstdZ  tBodyAccmadX  tBodyAccmadY  tBodyAccmadZ  \
# count   7352.000000   7352.000000   7352.000000   7352.000000   7352.000000
# mean      -0.510938     -0.604754     -0.630512     -0.526907     -0.606150
# std        0.502645      0.418687      0.424073      0.485942      0.414122
# min       -0.999873     -1.000000     -1.000000     -1.000000     -1.000000
# 25%       -0.978129     -0.980233     -0.993591     -0.978162     -0.980251
# 50%       -0.851897     -0.859365     -0.950709     -0.857328     -0.857143
# 75%       -0.034231     -0.262415     -0.292680     -0.066701     -0.265671
# max        0.916238      1.000000      1.000000      0.967664      1.000000
#
#        tBodyAccmaxX  ...  fBodyBodyGyroJerkMagkurtosis  \
# count   7352.000000  ...                   7352.000000
# mean      -0.468604  ...                     -0.625294
# std        0.544547  ...                      0.307584
# min       -1.000000  ...                     -0.999765
# 25%       -0.936219  ...                     -0.845573
# 50%       -0.881637  ...                     -0.711692
# 75%       -0.017129  ...                     -0.503878
# max        1.000000  ...                      0.956845
#
#        angletBodyAccMeangravity  angletBodyAccJerkMeangravityMean  \
# count               7352.000000                       7352.000000
# mean                   0.008684                          0.002186
# std                    0.336787                          0.448306
# min                   -0.976580                         -1.000000
# 25%                   -0.121527                         -0.289549
# 50%                    0.009509                          0.008943
# 75%                    0.150865                          0.292861
# max                    1.000000                          1.000000
#
#        angletBodyGyroMeangravityMean  angletBodyGyroJerkMeangravityMean  \
# count                    7352.000000                        7352.000000
# mean                        0.008726                          -0.005981
# std                         0.608303                           0.477975
# min                        -1.000000                          -1.000000
# 25%                        -0.482273                          -0.376341
# 50%                         0.008735                          -0.000368
# 75%                         0.506187                           0.359368
# max                         0.998702                           0.996078
#
#        angleXgravityMean  angleYgravityMean  angleZgravityMean      subject  \
# count        7352.000000        7352.000000        7352.000000  7352.000000
# mean           -0.489547           0.058593          -0.056515    17.413085
# std             0.511807           0.297480           0.279122     8.975143
# min            -1.000000          -1.000000          -1.000000     1.000000
# 25%            -0.812065          -0.017885          -0.143414     8.000000
# 50%            -0.709417           0.182071           0.003181    19.000000
# 75%            -0.509079           0.248353           0.107659    26.000000
# max             1.000000           0.478157           1.000000    30.000000
#
#           Activity
# count  7352.000000
# mean      3.643362
# std       1.744802
# min       1.000000
# 25%       2.000000
# 50%       4.000000
# 75%       5.000000
# max       6.000000
#
# [8 rows x 563 columns]

# %%
# checking if there is any null values in the data
train.isnull().values.any()
# Out:
# False

# %%
# countplot of activities
plt.figure(figsize=(15,10))
plt.rcParams['font.family'] = 'Dejavu Sans'
sns.set_style('whitegrid')
sns.countplot(x=train['ActivityName'],data=train)
plt.title('Countplot of Activities',fontsize=20)
plt.xlabel('Activity Name',fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.savefig('./img/countplot.jpg')
plt.show()

# %%
# countplot subject wise
plt.figure(figsize=(15,10))
plt.rcParams['font.family'] = 'Dejavu Sans'
sns.set_style('whitegrid')
plt.title('Data provided by each user', fontsize=20)
sns.countplot(x='subject',hue='ActivityName', data = train)
plt.xlabel('Subject',fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.savefig('./img/subject.jpg')
plt.show()

# %%
from sklearn.manifold import TSNE

# %%
# performs t-sne with different perplexity values and their repective plots..
def perform_tsne(X_data, y_data, perplexities, n_iter=1000, img_name_prefix='t-sne'):
        
    for index,perplexity in enumerate(perplexities):
        # perform t-sne
        print('\nperforming tsne with perplexity {} and with {} iterations at max'.format(perplexity, n_iter))
        X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
        print('Done..')
        
        # prepare the data for seaborn         
        print('Creating plot for this t-sne visualization..')
        df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})
        
        # draw the plot in appropriate place in the grid
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, size=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
        plt.title("Perplexity : {} and max_iter : {}".format(perplexity, n_iter))
        img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
        print('saving this plot as image in present working directory...')
        plt.savefig('./img/'+img_name)
        plt.show()
        print('Done')

# %%
X_pre_tsne = train.drop(['subject', 'Activity','ActivityName'], axis=1)
y_pre_tsne = train['ActivityName']
perform_tsne(X_data = X_pre_tsne,y_data=y_pre_tsne, perplexities =[2,5,10,20,50])
# Out:
# performing tsne with perplexity 2 and with 1000 iterations at max
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.813s...
# [t-SNE] Computed neighbors for 7352 samples in 33.101s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.635854
# [t-SNE] Computed conditional probabilities in 0.027s
# [t-SNE] Iteration 50: error = 124.6995468, gradient norm = 0.0297486 (50 iterations in 1.778s)
# [t-SNE] Iteration 100: error = 107.1261597, gradient norm = 0.0296371 (50 iterations in 1.452s)
# [t-SNE] Iteration 150: error = 100.9892883, gradient norm = 0.0195226 (50 iterations in 1.273s)
# [t-SNE] Iteration 200: error = 97.6119461, gradient norm = 0.0165091 (50 iterations in 1.235s)
# [t-SNE] Iteration 250: error = 95.3149185, gradient norm = 0.0113072 (50 iterations in 1.351s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 95.314919
# [t-SNE] Iteration 300: error = 4.1191416, gradient norm = 0.0015596 (50 iterations in 1.214s)
# [t-SNE] Iteration 350: error = 3.2107899, gradient norm = 0.0010070 (50 iterations in 1.179s)
# [t-SNE] Iteration 400: error = 2.7811310, gradient norm = 0.0007246 (50 iterations in 1.176s)
# [t-SNE] Iteration 450: error = 2.5179803, gradient norm = 0.0005668 (50 iterations in 1.178s)
# [t-SNE] Iteration 500: error = 2.3349943, gradient norm = 0.0004809 (50 iterations in 1.178s)
# [t-SNE] Iteration 550: error = 2.1975310, gradient norm = 0.0004182 (50 iterations in 1.203s)
# [t-SNE] Iteration 600: error = 2.0882926, gradient norm = 0.0003658 (50 iterations in 1.165s)
# [t-SNE] Iteration 650: error = 1.9981875, gradient norm = 0.0003360 (50 iterations in 1.230s)
# [t-SNE] Iteration 700: error = 1.9227941, gradient norm = 0.0003009 (50 iterations in 1.183s)
# [t-SNE] Iteration 750: error = 1.8578271, gradient norm = 0.0002785 (50 iterations in 1.183s)
# [t-SNE] Iteration 800: error = 1.8011805, gradient norm = 0.0002550 (50 iterations in 1.187s)
# [t-SNE] Iteration 850: error = 1.7511668, gradient norm = 0.0002410 (50 iterations in 1.321s)
# [t-SNE] Iteration 900: error = 1.7066191, gradient norm = 0.0002253 (50 iterations in 1.211s)
# [t-SNE] Iteration 950: error = 1.6664410, gradient norm = 0.0002122 (50 iterations in 1.209s)
# [t-SNE] Iteration 1000: error = 1.6301208, gradient norm = 0.0001997 (50 iterations in 1.206s)
# [t-SNE] KL divergence after 1000 iterations: 1.630121
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\ankit\anaconda3\envs\tf_gpu\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 5 and with 1000 iterations at max
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.787s...
# [t-SNE] Computed neighbors for 7352 samples in 34.016s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.961265
# [t-SNE] Computed conditional probabilities in 0.061s
# [t-SNE] Iteration 50: error = 114.0982895, gradient norm = 0.0228540 (50 iterations in 3.968s)
# [t-SNE] Iteration 100: error = 97.4230576, gradient norm = 0.0168378 (50 iterations in 1.537s)
# [t-SNE] Iteration 150: error = 93.0822678, gradient norm = 0.0100584 (50 iterations in 1.781s)
# [t-SNE] Iteration 200: error = 91.1437988, gradient norm = 0.0067626 (50 iterations in 1.758s)
# [t-SNE] Iteration 250: error = 89.9836349, gradient norm = 0.0054971 (50 iterations in 1.713s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 89.983635
# [t-SNE] Iteration 300: error = 3.5687172, gradient norm = 0.0014604 (50 iterations in 1.714s)
# [t-SNE] Iteration 350: error = 2.8105199, gradient norm = 0.0007519 (50 iterations in 1.627s)
# [t-SNE] Iteration 400: error = 2.4303889, gradient norm = 0.0005236 (50 iterations in 1.481s)
# [t-SNE] Iteration 450: error = 2.2134235, gradient norm = 0.0004075 (50 iterations in 1.438s)
# [t-SNE] Iteration 500: error = 2.0687129, gradient norm = 0.0003333 (50 iterations in 1.363s)
# [t-SNE] Iteration 550: error = 1.9636056, gradient norm = 0.0002825 (50 iterations in 1.381s)
# [t-SNE] Iteration 600: error = 1.8825690, gradient norm = 0.0002471 (50 iterations in 1.415s)
# [t-SNE] Iteration 650: error = 1.8173804, gradient norm = 0.0002221 (50 iterations in 1.332s)
# [t-SNE] Iteration 700: error = 1.7640047, gradient norm = 0.0001967 (50 iterations in 1.319s)
# [t-SNE] Iteration 750: error = 1.7188554, gradient norm = 0.0001805 (50 iterations in 1.311s)
# [t-SNE] Iteration 800: error = 1.6800764, gradient norm = 0.0001651 (50 iterations in 1.268s)
# [t-SNE] Iteration 850: error = 1.6463023, gradient norm = 0.0001539 (50 iterations in 1.241s)
# [t-SNE] Iteration 900: error = 1.6167861, gradient norm = 0.0001440 (50 iterations in 1.219s)
# [t-SNE] Iteration 950: error = 1.5901725, gradient norm = 0.0001371 (50 iterations in 1.220s)
# [t-SNE] Iteration 1000: error = 1.5665680, gradient norm = 0.0001270 (50 iterations in 1.273s)
# [t-SNE] KL divergence after 1000 iterations: 1.566568
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\ankit\anaconda3\envs\tf_gpu\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 10 and with 1000 iterations at max
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.833s...
# [t-SNE] Computed neighbors for 7352 samples in 35.289s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.133828
# [t-SNE] Computed conditional probabilities in 0.072s
# [t-SNE] Iteration 50: error = 105.7830276, gradient norm = 0.0200053 (50 iterations in 1.590s)
# [t-SNE] Iteration 100: error = 90.3573532, gradient norm = 0.0089252 (50 iterations in 1.499s)
# [t-SNE] Iteration 150: error = 87.2985687, gradient norm = 0.0063537 (50 iterations in 1.376s)
# [t-SNE] Iteration 200: error = 86.0452957, gradient norm = 0.0042830 (50 iterations in 1.386s)
# [t-SNE] Iteration 250: error = 85.3396378, gradient norm = 0.0040634 (50 iterations in 1.450s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.339638
# [t-SNE] Iteration 300: error = 3.1276848, gradient norm = 0.0013853 (50 iterations in 1.821s)
# [t-SNE] Iteration 350: error = 2.4843655, gradient norm = 0.0006482 (50 iterations in 1.559s)
# [t-SNE] Iteration 400: error = 2.1648190, gradient norm = 0.0004244 (50 iterations in 1.430s)
# [t-SNE] Iteration 450: error = 1.9805126, gradient norm = 0.0003153 (50 iterations in 1.665s)
# [t-SNE] Iteration 500: error = 1.8624818, gradient norm = 0.0002530 (50 iterations in 1.631s)
# [t-SNE] Iteration 550: error = 1.7795918, gradient norm = 0.0002104 (50 iterations in 2.072s)
# [t-SNE] Iteration 600: error = 1.7173346, gradient norm = 0.0001796 (50 iterations in 1.937s)
# [t-SNE] Iteration 650: error = 1.6685469, gradient norm = 0.0001604 (50 iterations in 1.938s)
# [t-SNE] Iteration 700: error = 1.6289047, gradient norm = 0.0001431 (50 iterations in 1.852s)
# [t-SNE] Iteration 750: error = 1.5963516, gradient norm = 0.0001285 (50 iterations in 2.057s)
# [t-SNE] Iteration 800: error = 1.5687182, gradient norm = 0.0001183 (50 iterations in 1.863s)
# [t-SNE] Iteration 850: error = 1.5449784, gradient norm = 0.0001096 (50 iterations in 1.515s)
# [t-SNE] Iteration 900: error = 1.5245630, gradient norm = 0.0001006 (50 iterations in 1.473s)
# [t-SNE] Iteration 950: error = 1.5070702, gradient norm = 0.0000944 (50 iterations in 1.470s)
# [t-SNE] Iteration 1000: error = 1.4914607, gradient norm = 0.0000907 (50 iterations in 1.535s)
# [t-SNE] KL divergence after 1000 iterations: 1.491461
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\ankit\anaconda3\envs\tf_gpu\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 20 and with 1000 iterations at max
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.924s...
# [t-SNE] Computed neighbors for 7352 samples in 36.739s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.274335
# [t-SNE] Computed conditional probabilities in 0.157s
# [t-SNE] Iteration 50: error = 97.9952469, gradient norm = 0.0140665 (50 iterations in 2.317s)
# [t-SNE] Iteration 100: error = 83.8546448, gradient norm = 0.0063030 (50 iterations in 2.291s)
# [t-SNE] Iteration 150: error = 81.8824158, gradient norm = 0.0039175 (50 iterations in 1.743s)
# [t-SNE] Iteration 200: error = 81.1659393, gradient norm = 0.0024301 (50 iterations in 1.647s)
# [t-SNE] Iteration 250: error = 80.7852859, gradient norm = 0.0020962 (50 iterations in 1.801s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.785286
# [t-SNE] Iteration 300: error = 2.6988380, gradient norm = 0.0013027 (50 iterations in 1.665s)
# [t-SNE] Iteration 350: error = 2.1652722, gradient norm = 0.0005781 (50 iterations in 1.593s)
# [t-SNE] Iteration 400: error = 1.9154543, gradient norm = 0.0003474 (50 iterations in 1.591s)
# [t-SNE] Iteration 450: error = 1.7687712, gradient norm = 0.0002471 (50 iterations in 1.506s)
# [t-SNE] Iteration 500: error = 1.6744519, gradient norm = 0.0001932 (50 iterations in 1.548s)
# [t-SNE] Iteration 550: error = 1.6103556, gradient norm = 0.0001581 (50 iterations in 1.558s)
# [t-SNE] Iteration 600: error = 1.5637681, gradient norm = 0.0001342 (50 iterations in 1.509s)
# [t-SNE] Iteration 650: error = 1.5283297, gradient norm = 0.0001164 (50 iterations in 1.625s)
# [t-SNE] Iteration 700: error = 1.5007646, gradient norm = 0.0001041 (50 iterations in 1.571s)
# [t-SNE] Iteration 750: error = 1.4787382, gradient norm = 0.0000957 (50 iterations in 1.526s)
# [t-SNE] Iteration 800: error = 1.4609846, gradient norm = 0.0000877 (50 iterations in 1.556s)
# [t-SNE] Iteration 850: error = 1.4464073, gradient norm = 0.0000818 (50 iterations in 1.563s)
# [t-SNE] Iteration 900: error = 1.4343376, gradient norm = 0.0000788 (50 iterations in 1.598s)
# [t-SNE] Iteration 950: error = 1.4245614, gradient norm = 0.0000743 (50 iterations in 1.608s)
# [t-SNE] Iteration 1000: error = 1.4165157, gradient norm = 0.0000706 (50 iterations in 1.594s)
# [t-SNE] KL divergence after 1000 iterations: 1.416516
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\ankit\anaconda3\envs\tf_gpu\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 50 and with 1000 iterations at max
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.799s...
# [t-SNE] Computed neighbors for 7352 samples in 34.892s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.437672
# [t-SNE] Computed conditional probabilities in 0.375s
# [t-SNE] Iteration 50: error = 84.6154175, gradient norm = 0.0355075 (50 iterations in 2.604s)
# [t-SNE] Iteration 100: error = 75.7518463, gradient norm = 0.0042216 (50 iterations in 2.526s)
# [t-SNE] Iteration 150: error = 74.6823578, gradient norm = 0.0020775 (50 iterations in 2.280s)
# [t-SNE] Iteration 200: error = 74.3120041, gradient norm = 0.0018681 (50 iterations in 2.277s)
# [t-SNE] Iteration 250: error = 74.1275406, gradient norm = 0.0011055 (50 iterations in 2.300s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.127541
# [t-SNE] Iteration 300: error = 2.1746109, gradient norm = 0.0012059 (50 iterations in 2.110s)
# [t-SNE] Iteration 350: error = 1.7690406, gradient norm = 0.0004908 (50 iterations in 1.972s)
# [t-SNE] Iteration 400: error = 1.5979186, gradient norm = 0.0002820 (50 iterations in 2.022s)
# [t-SNE] Iteration 450: error = 1.5029780, gradient norm = 0.0001903 (50 iterations in 2.001s)
# [t-SNE] Iteration 500: error = 1.4422206, gradient norm = 0.0001415 (50 iterations in 2.054s)
# [t-SNE] Iteration 550: error = 1.4000509, gradient norm = 0.0001138 (50 iterations in 2.066s)
# [t-SNE] Iteration 600: error = 1.3702893, gradient norm = 0.0000942 (50 iterations in 2.065s)
# [t-SNE] Iteration 650: error = 1.3483684, gradient norm = 0.0000841 (50 iterations in 2.077s)
# [t-SNE] Iteration 700: error = 1.3321249, gradient norm = 0.0000751 (50 iterations in 2.097s)
# [t-SNE] Iteration 750: error = 1.3202938, gradient norm = 0.0000713 (50 iterations in 2.118s)
# [t-SNE] Iteration 800: error = 1.3113289, gradient norm = 0.0000662 (50 iterations in 2.056s)
# [t-SNE] Iteration 850: error = 1.3038324, gradient norm = 0.0000611 (50 iterations in 2.092s)
# [t-SNE] Iteration 900: error = 1.2973671, gradient norm = 0.0000568 (50 iterations in 2.079s)
# [t-SNE] Iteration 950: error = 1.2919742, gradient norm = 0.0000539 (50 iterations in 2.124s)
# [t-SNE] Iteration 1000: error = 1.2873851, gradient norm = 0.0000536 (50 iterations in 2.123s)
# [t-SNE] KL divergence after 1000 iterations: 1.287385
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\ankit\anaconda3\envs\tf_gpu\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
